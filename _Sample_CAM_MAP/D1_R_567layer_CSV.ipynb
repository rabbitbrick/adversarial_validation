# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_loss(results, title, ylim=None, figsize=(15, 15)):
    """
    Plot the loss metrics from a DataFrame file
    
    Arguments:
        results (pd.DataFrame): DataFrame containing loss metrics
        title (string): Title for the plot
        ylim (float): Limit for the plot's y axis, default=None
        figsize (tuple of ints): Figure size, default=(15, 15)
    """
    
    plt.figure(figsize=figsize)

    for name, result in results:
        val = plt.plot(range(len((result['epoch']))), result['val_loss'],
                       '--', label=name.title()+', Validation', lw=3.0)
        plt.plot(range(len((result['epoch']))), result['loss'], color=val[0].get_color(),
                 label=name.title()+', Training', lw=3.0)

    plt.title(title)
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.ylim(ylim)
    plt.grid(lw=2, ls='--')

# %%
def plot_accuracy(results, title, x_range=20, figsize=(15, 15)):
    """
    Plot the accuracy metrics from a DataFrame file
    
    Arguments:
        results (pd.DataFrame): DataFrame containing accuracy metrics
        title (string): Title for the plot
        ylim (float): Limit for the plot's y axis, default=None
        figsize (tuple of ints): Figure size, default=(15, 15)
    """    
    
    plt.figure(figsize=figsize)

    for name, result in results:
        val = plt.plot(range(len((result['epoch']))), result['val_accuracy'],
                       '--', label=name.title()+', Validation', lw=3.0)
        plt.plot(range(len((result['epoch']))), result['accuracy'], color=val[0].get_color(),
                 label=name.title()+', Training', lw=3.0)

    plt.title(title)
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(lw=2, ls='--')

# %%
five_layer = pd.read_csv("../D1/5-layer_double_adam_512_aug_bn_dropout01_explr_D1.csv")
six_layer = pd.read_csv("../D1/6-layer_double_adam_512_aug_bn_dropout01_explr_D1.csv")
seven_layer = pd.read_csv("../D1/7-layer_double_adam_512_aug_bn_dropout01_explr_D1.csv")


plot_loss([('5 Layers',  five_layer),
           ('6 Layers', six_layer),
           ('7 Layers', seven_layer)],
          'D1 Loss- 5, 6, 7 Conv Layers')



plot_accuracy([('5 Layers',  five_layer),
           ('6 Layers', six_layer),
           ('7 Layers', seven_layer)],
          'D1 Accuracy- 5, 6, 7 Conv Layers')

# %%
five_layer = pd.read_csv("../D2/5-layer_double_adam_512_aug_bn_dropout01_explr_D2.csv")
six_layer = pd.read_csv("../D2/6-layer_double_adam_512_aug_bn_dropout01_explr_D2.csv")
seven_layer = pd.read_csv("../D2/7-layer_double_adam_512_aug_bn_dropout01_explr_D2.csv")


plot_loss([('5 Layers',  five_layer),
           ('6 Layers', six_layer),
           ('7 Layers', seven_layer)],
          'D2 Loss- 5, 6, 7 Conv Layers')



plot_accuracy([('5 Layers',  five_layer),
           ('6 Layers', six_layer),
           ('7 Layers', seven_layer)],
          'D2 Accuracy- 5, 6, 7 Conv Layers')

# %%
five_layer = pd.read_csv("../D3/5-layer_double_adam_512_aug_bn_dropout01_explr_D3.csv")
six_layer = pd.read_csv("../D3/6-layer_double_adam_512_aug_bn_dropout01_explr_D3.csv")
seven_layer = pd.read_csv("../D3/7-layer_double_adam_512_aug_bn_dropout01_explr_D3.csv")


plot_loss([('5 Layers',  five_layer),
           ('6 Layers', six_layer),
           ('7 Layers', seven_layer)],
          'D3 Loss- 5, 6, 7 Conv Layers')



plot_accuracy([('5 Layers',  five_layer),
           ('6 Layers', six_layer),
           ('7 Layers', seven_layer)],
          'D3 Accuracy- 5, 6, 7 Conv Layers')

# %%
D1_five_layer = pd.read_csv("../D1/5-layer_double_adam_512_aug_bn_dropout01_explr_D1.csv")
D1_six_layer = pd.read_csv("../D1/6-layer_double_adam_512_aug_bn_dropout01_explr_D1.csv")
D1_seven_layer = pd.read_csv("../D1/7-layer_double_adam_512_aug_bn_dropout01_explr_D1.csv")

D2_five_layer = pd.read_csv("../D2/5-layer_double_adam_512_aug_bn_dropout01_explr_D2.csv")
D2_six_layer = pd.read_csv("../D2/6-layer_double_adam_512_aug_bn_dropout01_explr_D2.csv")
D2_seven_layer = pd.read_csv("../D2/7-layer_double_adam_512_aug_bn_dropout01_explr_D2.csv")

D3_five_layer = pd.read_csv("../D3/5-layer_double_adam_512_aug_bn_dropout01_explr_D3.csv")
D3_six_layer = pd.read_csv("../D3/6-layer_double_adam_512_aug_bn_dropout01_explr_D3.csv")
D3_seven_layer = pd.read_csv("../D3/7-layer_double_adam_512_aug_bn_dropout01_explr_D3.csv")


plot_loss([('D1_5 Layers', D1_five_layer),
           ('D1_6 Layers', D1_six_layer),
           ('D1_7 Layers', D1_seven_layer),
           ('D2_5 Layers', D2_five_layer),
           ('D2_6 Layers', D2_six_layer),
           ('D2_7 Layers', D2_seven_layer),
           ('D3_5 Layers', D3_five_layer),
           ('D3_6 Layers', D3_six_layer),
           ('D3_7 Layers', D3_seven_layer)],
          'D3 Loss- 5, 6, 7 Conv Layers')

plot_accuracy([('D1_5 Layers', D1_five_layer),
           ('D1_6 Layers', D1_six_layer),
           ('D1_7 Layers', D1_seven_layer),
           ('D2_5 Layers', D2_five_layer),
           ('D2_6 Layers', D2_six_layer),
           ('D2_7 Layers', D2_seven_layer),
           ('D3_5 Layers', D3_five_layer),
           ('D3_6 Layers', D3_six_layer),
           ('D3_7 Layers', D3_seven_layer)],
          'D3 Loss- 5, 6, 7 Conv Layers')
